# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from NRCS_report import Report
import os, ssl 
from urllib.request import urlopen
from bs4 import BeautifulSoup
# Out:
# /Users/gregmcc/.pyenv/versions/3.8.6/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
if (not os.environ.get('PYTHONHTTPSVERIFY', '') and getattr(ssl, '_create_unverified_context', None)):
    ssl._create_default_https_context = ssl._create_unverified_context

# %%
#Print out site info
rep = Report()

rep.GetIDs('SNTL')

rep.SiteIDs.sample(10)
# Out:
#      ntwk state          site_name ts         start    lat     lon   elev  \
# 446  SNTL    NV     Cave Mountain      2011-October  39.16 -114.61  10578
# 0    SNTL    AK    Alexander Lake       2014-August  61.75 -150.89    160
# 572  SNTL    OR            Tipton      1978-October  44.66 -118.43   5150
# 703  SNTL    UT      Vernon Creek      1978-October  39.94 -112.41   7401
# 335  SNTL    MT      Carrot Basin      1966-October  44.96 -111.29   9000
# 517  SNTL    OR  Emigrant Springs      1979-October  45.56 -118.45   3800
# 776  SNTL    WA       Swift Creek      2001-October  46.16 -122.18   4440
# 331  SNTL    MT        Box Canyon      1976-October  45.27 -110.25   6670
# 706  SNTL    UT        Widtsoe #3      1978-October  37.84 -111.88   9640
# 134  SNTL    CO    Burro Mountain      1978-October  39.88  -107.6   9400
#
#                 county           huc  site_id                       huc_name
# 446         White Pine  160600080402     1152                 Bastian Creek
# ...

# %%
TimeInfo={'month':2,'timeofmonth':'end','years':(2010,2019)}
DataTypes={'WTEQ':'value','SNWD':'value'}
SiteIDs = [['CA',391,'SNTL'],['AK',1062,'SNTL'],['CA',1067,'SNTL'],['CA',1051,'SNTL']]

rep.GetReport(TimeOption='monthly',TimeInfo=TimeInfo,\
              DataTypes=DataTypes,SiteIDs=SiteIDs)

# %%
N = rep.df_rep.shape[0]
rep.df_rep.head(N)
# Out:
#         date state site_id  WTEQ SNWD
# 0   Feb 2010    AK    1062  11.1   35
# 1   Feb 2010    CA    1051  22.5   77
# 2   Feb 2010    CA    1067  26.7   87
# 3   Feb 2010    CA     391  12.7   38
# 4   Feb 2011    AK    1062   8.9   36
# 5   Feb 2011    CA    1051  31.2  102
# 6   Feb 2011    CA    1067  35.2  107
# 7   Feb 2011    CA     391  15.4   48
# 8   Feb 2012    AK    1062  15.6   64
# 9   Feb 2012    CA    1051   7.2   34
# 10  Feb 2012    CA    1067  10.4   36
# 11  Feb 2012    CA     391   7.7   29
# 12  Feb 2013    AK    1062  13.6   47
# 13  Feb 2013    CA    1051  18.8   49
# 14  Feb 2013    CA    1067  24.6   63
# 15  Feb 2013    CA     391  10.7   34
# 16  Feb 2014    AK    1062   6.2   15
# 17  Feb 2014    CA    1051    14   50
# 18  Feb 2014    CA    1067  16.3   64
# 19  Feb 2014    CA     391     6   20
# 20  Feb 2015    AK    1062   5.7   13
# 21  Feb 2015    CA    1051   8.8   27
# 22  Feb 2015    CA    1067  13.1   41
# 23  Feb 2015    CA     391   3.5   10
# ...

# %%
rep.URL #this is the webpage with the data in the above table. For ease of data manupulation I made the station 
    #identity (state+site_id) features
# Out:
# 'https://wcc.sc.egov.usda.gov/reportGenerator/view/customMultiTimeSeriesGroupByStationReport/monthly/end_of_period/391:CA:SNTL%7C1062:AK:SNTL%7C1067:CA:SNTL%7C1051:CA:SNTL%7Cid=%22%22%7Cname/2010-01-01,2019-12-31:M%7C2/stationId,name,WTEQ::value,SNWD::value?fitToScreen=false'
